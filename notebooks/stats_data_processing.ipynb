# %%
import pandas as pd

# %%
data = pd.read_csv("../data/statsBank/HFUDD16_Final_Readable.csv", encoding='utf-8', nrows=1000)

# %%
data.head()
# Out:
#    Region_Code         Region_Name     Education_Level   Socioeconomic_Status  \
# 0           81  Region Nordjylland  Bachelor and lower  Enrolled in education
# 1           81  Region Nordjylland  Bachelor and lower  Enrolled in education
# 2           81  Region Nordjylland  Bachelor and lower  Enrolled in education
# 3           81  Region Nordjylland  Bachelor and lower  Enrolled in education
# 4           81  Region Nordjylland  Bachelor and lower  Enrolled in education
#
#   Industry_Group Age_Group  Year  Count
# 0  Manufacturing     15-19  2008   1752
# 1  Manufacturing     15-19  2009   1408
# 2  Manufacturing     15-19  2010   1417
# 3  Manufacturing     15-19  2011   1376
# 4  Manufacturing     15-19  2012   1276
